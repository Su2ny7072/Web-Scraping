# %%
# !pip install selenium

import selenium

import pandas as pd

from selenium import webdriver

import warnings

warnings.filterwarnings('ignore')

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

from selenium.webdriver.common.by import By



import time
# Out:
# Requirement already satisfied: selenium in c:\users\su2ny\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: trio~=0.17 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: sniffio in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: pycparser in c:\users\su2ny\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\su2ny\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\su2ny\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\su2ny\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(4)

url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(6)

# %%
#Creating blank list
Rank=[]
Name=[]
Artist=[]
Upload_date=[]
Views=[]

#Scraping Rank
rank=driver.find_elements(By.XPATH,"/table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[1]")
for i in rank:
    Rank.append(i.text)

#Scraping Name
name=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[2]")
for i in name:
    Name.append(i.text)
    
#Scraping Artist
artist=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[3]")
for i in artist:
    Artist.append(i.text)
    
    
#Scraping Views
views=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[4]")
for i in views:
    Views.append(i.text)
    
    
#Scraping Upload_date
upload_date=driver.find_elements(By.XPATH,"//table[@class='wikitable sortable jquery-tablesorter'][1]/tbody/tr/td[5]")
for i in upload_date:
    Upload_date.append(i.text)
    
Youtube_viewed=pd.DataFrame({})
Youtube_viewed['Rank']=Rank
Youtube_viewed['Name']=Name
Youtube_viewed['Artist']=Artist
Youtube_viewed['Upload_date']=Upload_date
Youtube_viewed['Views']=Views
Youtube_viewed
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Artist, Upload_date, Views]
# Index: []

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe") 
time.sleep(4)

url = "https://www.bcci.tv/"
driver.get(url)
time.sleep(6)

# %%
#click on international
international=driver.find_element(By.XPATH,"/html/body/div[3]/div/div[2]/div[2]/nav/ul/li[1]/div[2]")
international.click()
time.sleep(3)

# click on fixtures
fixtures= driver.find_element(By.XPATH,"/html/body/div[3]/div/div[2]/div[2]/nav/ul/li[1]/div[2]/div/ul/li[1]/a")
fixtures.click()
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 #click on international
# ----> 2 international=driver.find_element(By.XPATH,"/html/body/div[3]/div/div[2]/div[2]/nav/ul/li[1]/div[2]")
#       3 international.click()
#       4 time.sleep(3)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[3]/div/div[2]/div[2]/nav/ul/li[1]/div[2]"}
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0086019F]
# 	(No symbol) [0x008603AB]
# 	(No symbol) [0x0088EE62]
# 	(No symbol) [0x0087AF14]
# 	(No symbol) [0x0088D57C]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75BC7D69+25]
# 	RtlInitializeExceptionChain [0x774AB74B+107]
# 	RtlClearBits [0x774AB6CF+191]

# %%
#Creating Empty list
Match_title=[]
Series=[]
Place=[]
Date=[]
Time=[]

#Scraping Match_title
match_title= driver.find_elements(By.XPATH,"//strong[@class='fixture__name fixture__name--with-margin']")
for i in match_title:
    Match_title.append(i.text)
    
#Scraping Series
series= driver.find_elements(By.XPATH,"//span[@class='u-unskewed-text fixture__tournament-label u-truncated']")
for i in series:
    Series.append(i.text)
    
#Scraping Place
place= driver.find_elements(By.XPATH,"//p[@class='fixture__additional-info']/span")
for i in place:
    Place.append(i.text)   
    
#Scraping Date
date= driver.find_elements(By.XPATH,"//div[@class='fixture__full-date']")
for i in date:
    Date.append(i.text)   
    
#Scraping Time
time= driver.find_elements(By.XPATH,"//span[@class='fixture__time']")
for i in time:
    Time.append(i.text) 

Fixture=pd.DataFrame({})
Fixture['Match_title']=Match_title
Fixture['Series']=Series
Fixture['Place']=Place
Fixture['Date']=Date
Fixture['Time']=Time
Fixture
# Out:
# Empty DataFrame
# Columns: [Match_title, Series, Place, Date, Time]
# Index: []

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe")

url = "https://www.statisticstimes.com/"
driver.get(url)

# %%
#Click Economy
Economy=driver.find_element(By.XPATH,"//*[@id='top']/div[2]/div[2]/button")
Economy.click()

# %%
#Click India
India= driver.find_element(By.XPATH,"//*[@id='top']/div[2]/div[2]/div/a[3]")
India.click()

# %%
#Click on State GPD
GDP= driver.find_element(By.XPATH,"/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
GDP.click()

# %%
# creating empty list
Rank = []
State = []
GSDP1 = []
GSDP2 = []
Share = []
GDP_billion = []

# scraping Rank
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[1]"):
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("_")
    
# scraping State
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[2]"):
        State.append(i.text)
except NoSuchElementException:
    State.append("_")
    
# scraping GSDP at current price (19-20)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[3]"):
        GSDP1.append(i.text)
except NoSuchElementException:
    GSDP1.append("_")
    
# scraping GSDP at current price (18-19)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[4]"):
        GSDP2.append(i.text)
except NoSuchElementException:
    GSDP2.append("_")
    
# scraping Share (18-19)
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[5]"):
        Share.append(i.text)
except NoSuchElementException:
    Share.append("_")
    
# scraping GDP $ billion
try:
    for i in driver.find_elements(By.XPATH,"//table[@class='display dataTable']/tbody/tr/td[6]"):
        GDP_billion.append(i.text)
except NoSuchElementException:
    GDP_billion.append("_")
    
    
# creating DataFrame from the scraped data
GDP = pd.DataFrame({})
GDP['Rank'] = Rank
GDP['State'] = State
GDP['GSDP at current price (19-20)'] = GSDP1
GDP['GSDP at current price (18-19)'] = GSDP2
GDP['Share (18-19)'] = Share
GDP['GDP($ billion)'] = GDP_billion
GDP
# Out:
#    Rank                      State GSDP at current price (19-20)  \
# 0     1                Maharashtra                             -
# 1     2                 Tamil Nadu                     1,845,853
# 2     3              Uttar Pradesh                     1,687,818
# 3     4                    Gujarat                             -
# 4     5                  Karnataka                     1,631,977
# ..  ...                        ...                           ...
# 61   29                     Sikkim                        28,391
# 62   30                   Nagaland                             -
# 63   31          Arunachal Pradesh                             -
# 64   32                    Mizoram                        24,424
# 65   33  Andaman & Nicobar Islands                             -
#
#    GSDP at current price (18-19) Share (18-19) GDP($ billion)
# 0                      2,632,792        13.94%        399.921
# 1                      1,630,208         8.63%        247.629
# 2                      1,584,764         8.39%        240.726
# 3                      1,502,899         7.96%        228.290
# 4                      1,493,127         7.91%        226.806
# ..                           ...           ...            ...
# 61                        25,141         0.15%         17,060
# 62                        24,534         0.15%              -
# 63                        22,488         0.13%              -
# 64                        20,947         0.13%         17,797
# 65                             -             -              -
#
# [66 rows x 6 columns]

# %%
# !pip install selenium

import selenium

import pandas as pd

from selenium import webdriver

import warnings

warnings.filterwarnings('ignore')

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

from selenium.webdriver.common.by import By



import time
# Out:
# Requirement already satisfied: selenium in c:\users\su2ny\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: outcome in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: pycparser in c:\users\su2ny\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\su2ny\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\su2ny\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\su2ny\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe")

url = "https://github.com/"
driver.get(url)

# %%
# getting explore button and clicking on it
explore = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()

# selecting trending option
trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a")
urls = trend_url.get_attribute("href")
driver.get(urls)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [5], in <cell line: 2>()
#       1 # getting explore button and clicking on it
# ----> 2 explore = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details").click()
#       4 # selecting trending option
#       5 trend_url = driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a")
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details"}
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0086019F]
# 	(No symbol) [0x008603AB]
# 	(No symbol) [0x0088EE62]
# 	(No symbol) [0x0087AF14]
# 	(No symbol) [0x0088D57C]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75B97D69+25]
# 	RtlInitializeExceptionChain [0x775AB74B+107]
# 	RtlClearBits [0x775AB6CF+191]

# %%
# creating empty list
URLs = []
repository_title = []
Description = []
Contributors = []
Language = []
lang = []

# fetching urls for each repository
repository = driver.find_elements(By.XPATH,"//h1[@class='h3 lh-condensed']//a")
for i in repository:
    URLs.append(i.get_attribute("href"))
    
# scraping Repository title data
title = driver.find_elements(By.XPATH,"//h1[@class = 'h3 lh-condensed']")
for i in title:
    repository_title.append(i.text)
    
# scraping data from all repository page
for i in URLs:
    driver.get(i)
    time.sleep(5)
    
    # scraping Repository Description data 
    try:
        desc = driver.find_element(By.XPATH,"//p[@class='f4 mt-3']")
        Description.append(desc.text)
    except NoSuchElementException:
        Description.append('-')
        
        
    # scraping Contributors Count data
    try:
        contributor = driver.find_element(By.XPATH,"//*[contains(text(),'    Contributors ')]")
        Contributors.append(contributor.text.replace('Contributors',''))
    except NoSuchElementException:
        Contributors.append('-')
    
    
    # scraping Languages used data
    try:
        for i in driver.find_element(By.XPATH,"//ul[@class= 'list-style-none']//li//span[1]"):
            lang.append(i.text)
        Language.append(lang)
    except NoSuchElementException:
        Language.append('-')
        
        
# Data Framing
Github = pd.DataFrame({})
Github['Repository Title'] = repository_title
Github['Repository Description'] = Description
Github['Contributors Count'] = Contributors
Github['Language Used'] = Language
Github
# Out:
# Empty DataFrame
# Columns: [Repository Title, Repository Description, Contributors Count, Language Used]
# Index: []

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe")

url = "https://www.billboard.com/"
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [25], in <cell line: 4>()
#       1 driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe")
#       3 url = "https://www.billboard.com/"
# ----> 4 driver.get(url)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:449, in WebDriver.get(self, url)
#     447 def get(self, url: str) -> None:
#     448     """Loads a web page in the current browser session."""
# --> 449     self.execute(Command.GET, {"url": url})
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0081D0D3]
# 	(No symbol) [0x0087EA8B]
# 	(No symbol) [0x0088D093]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75B97D69+25]
# 	RtlInitializeExceptionChain [0x775AB74B+107]
# 	RtlClearBits [0x775AB6CF+191]

# %%
# clicking on option button
charts=driver.find_element(By.XPATH,"//a[@class='header__main-link header__main-link--charts']").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 # clicking on option button
# ----> 2 charts=driver.find_element(By.XPATH,"//a[@class='header__main-link header__main-link--charts']").click()
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0081D0D3]
# 	(No symbol) [0x0087EA8B]
# 	(No symbol) [0x0088D093]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75B97D69+25]
# 	RtlInitializeExceptionChain [0x775AB74B+107]
# 	RtlClearBits [0x775AB6CF+191]

# %%
# creating empty lists
Song_Name = []
Artist_Name =[]
Last_week_rank = []
Peak_rank = []
Weeks_on_board = []

# getting urls for top 100 songs
urls = driver.find_element (By.XPATH,"//li[@class='header__submenu__list__element']//a")
page_url = urls.get_attribute("href")
driver.get(page_url)
time.sleep(4)
# Out:
#   Input In [8]
#     urls = driver.find_element int(By.XPATH,"//li[@class='header__submenu__list__element']//a")
#                                ^
# SyntaxError: invalid syntax

# %%
# !pip install selenium

import selenium

import pandas as pd

from selenium import webdriver

import warnings

warnings.filterwarnings('ignore')

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

from selenium.webdriver.common.by import By



import time
# Out:
# Requirement already satisfied: selenium in c:\users\su2ny\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio~=0.17 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\su2ny\anaconda3\lib\site-packages (from selenium) (2021.10.8)
# Requirement already satisfied: idna in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\su2ny\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: pycparser in c:\users\su2ny\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: wsproto>=0.14 in c:\users\su2ny\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\su2ny\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\su2ny\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe")

url = "https://www.naukri.com/hr-recruiters-consultants"
driver.get(url)
time.sleep(5)

# %%
# fetching urls to navigate recruiter page
recruiter = driver.find_element(By.XPATH,"//a[@title='Search Recruiters']")
page_url = recruiter.get_attribute("href")

driver.get(page_url)
time.sleep(3)

# %%
# fetching search button, sending keys and clicking on it
search = driver.find_element(By.XPATH,"//div[@class='inpWrap']//input")
search.send_keys("Data Science")

btn = driver.find_element(By.XPATH,"//button[@class='fl qsbSrch blueBtn']").click()
time.sleep(3)

# %%
# creating empty lists
Name = []
Designation = []
Company = []
Skills = []
Location = []

# scraping data of Names
for i in driver.find_elements(By.XPATH,"//span[@class='fl ellipsis']"):
    Name.append(i.text)
time.sleep(3)


# scraping data of Designation
for i in driver.find_elements(By.XPATH,"//span[@class='ellipsis clr']"):
    Designation.append(i.text)
time.sleep(3)


# scraping data of Company Name
for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]/a[2]"):
    Company.append(i.text)
time.sleep(3)


# scraping data of Skills
for i in driver.find_elements(By.XPATH,"//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Skills.append(i.text)
    except NoSuchElementException:
        Skills.append('-')
time.sleep(3)


# scraping data of Location
for i in driver.find_elements(By.XPATH,"//div[@class='vcard']//p[1]/span/small"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        Location.append(i.text)
    except NoSuchElementException:
        Location.append('-')
time.sleep(3)


# creating dataframe for scraped data
Naukri = pd.DataFrame({})
Naukri['Name'] = Name[:49]
Naukri['Designation'] = Designation[:49]
Naukri['Company'] = Company[:49]
Naukri['Skills'] = Skills[:49]
Naukri['Location'] = Location[:49]
Naukri
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                Kalpana Dumpala
# 11                                        Mubarak
# 12                                 Kushal Rastogi
# 13                             Mahesh Babu Channa
# 14                                 Priyanka Akiri
# 15                                   Kapil Devang
# 16                             Vaishnavi Kudalkar
# 17                                Sakshi Chhikara
# 18                                    Ruchi Dhote
# 19                                  Manisha Yadav
# 20                                    Riya Rajesh
# 21                           Rashmi Bhattacharjee
# 22                                  Faizan Kareem
# 23                                 Rithika dadwal
# 24                             Sandhya Khandagale
# 25                                      Shaun Rao
# 26                               Deeparchi Sharma
# 27                                  Azahar Shaikh
# 28                                          Manas
# 29                                          kumar
# 30                                   Sunil Vedula
# 31                                    Rajat Kumar
# 32                                Dhruv Dev Dubey
# 33                                  Avnish Mishra
# 34                                      Jayanth N
# 35                                         Avodha
# 36                                    Priya Khare
# 37                                    Amit Sharma
# 38                                          Kanan
# 39                           Shashikant Chaudhary
# 40                                           Brad
# 41                                   Rutuja Pawar
# 42                            Madhusudhan Sridhar
# 43                                    Ankit Sinha
# 44                                 Gaurav Chouhan
# 45                                   Rashi Kacker
# 46                                        Ashwini
# 47                                   Balaji Kolli
# 48                                 Rajani Nagaraj
#
#                                    Designation  \
# 0                                   HR Manager
# 1                            Company Recruiter
# 2                                   Company HR
# 3                            Company Recruiter
# 4                                  Founder CEO
# 5                  Recruitment Lead Consultant
# 6                            Programme Manager
# 7                             HR Administrator
# 8                                     Director
# 9                               Human Resource
# 10                            Executive Hiring
# 11                                  Company HR
# 12                                  Company HR
# 13                                HR Team Lead
# 14                                  HR Manager
# 15                                  HR Manager
# 16                                HR Executive
# 17                        Assistant Manager HR
# 18         Senior Executive Talent Acquisition
# 19                                HR Executive
# 20                  Manager Talent Acquisition
# 21                                     HR Head
# 22                                  HR MANAGER
# 23                                HR Recruiter
# 24                                HR Recruiter
# 25                     Manager Human Resources
# 26                           Company Recruiter
# 27                           Company Recruiter
# 28                     Lead Talent acquisition
# 29                                  Proprietor
# 30                                         CEO
# 31                                 Founder CEO
# 32                    Company Recruitment Head
# 33  Senior Technical &amp; Corporate Recruiter
# 34                             Project Manager
# 35              Business Development Associate
# 36                              Senior Manager
# 37                                  Consultant
# 38                senior technology instructor
# 39                    HR Recruiter/HR Excutive
# 40               Manager, Technical Recruiting
# 41                         Technical Recruiter
# 42                             Erp Implementer
# 43                              Head Analytics
# 44                     Chief Technical Officer
# 45                          Sr Product Manager
# 46                    Director Global Delivery
# 47                                  Co Founder
# 48                                  HR Manager
#
#                                            Company  \
# 0                             Data Science Network
# 1                    Shore Infotech India Pvt. Ltd
# 2                         MARSIAN Technologies LLP
# 3            Enerlytics Software Solutions Pvt Ltd
# 4                                  LibraryXProject
# 5       Apidel Technologies Division of Transpower
# 6                                             IFMR
# 7                      Techvantage Systems Pvt Ltd
# 8                       Weupskill- Live Wire India
# 9                 CBL Data Science Private Limited
# 10                              Innominds Software
# 11                                        MoneyTap
# 12              QuantMagnum Technologies Pvt. Ltd.
# 13                               SocialPrachar.com
# 14                   Infinitive Software Solutions
# 15                                  BISP Solutions
# 16                             Codeachive learning
# 17                   BIZ INFOTECNO PRIVATE LIMITED
# 18                           Bristlecone India Ltd
# 19                                        Easi Tax
# 20                     Novelworx Digital Solutions
# 21         AXESTRACK SOFTWARE SOLUTIONS PRIVATE...
# 22                   FirstTech Consaltants Pvt.Ltd
# 23                                Affine Analytics
# 24                 Compumatrice Multimedia Pvt Ltd
# 25                              Exela Technologies
# 26                                          ZIGRAM
# 27                 NEAL ANALYTICS SERVICES PVT LTD
# 28      Autumn Leaf Consulting Services Private...
# 29                                         trainin
# 30                            Nanoprecise Sci Corp
# 31                  R.S Consultancy &amp; Services
# 32                               NETAPS FOUNDATION
# 33                   RMS Risk Management Solutions
# 34        Dollarbird Information Services Pvt, Ltd
# 35                              Nikitha Palaparthi
# 36                          Independent Consultant
# 37                                 ASCO consulting
# 38                                         NY INST
# 39  3D India Staffing Research &amp; Consulting...
# 40                                     O.C. Tanner
# 41                                   Demand Matrix
# 42                             MADHUSUDHAN SRIDHAR
# 43                                  Suntech Global
# 44                        Strategic Consulting Lab
# 45                            Impel Labs Pvt. Ltd.
# 46                                    MRP Advisers
# 47                   Saras Solutions India Pvt Ltd
# 48                                     WildJasmine
#
#                                                Skills  \
# 0   Classic ASP Developer, Internet Marketing Prof...
# 1   .Net, Java, Data Science, Linux Administration...
# 2   Data Science, Artificial Intelligence, Machine...
# 3   Mean Stack, javascript, angularjs, mongodb, We...
# 4   Hadoop, Spark, Digital Strategy, Data Architec...
# 5   Analytics, Business Intelligence, Business Ana...
# 6                                        Data Science
# 7   Machine Learning, algorithms, Go Getter, Compu...
# 8   Technical Training, Software Development, Pres...
# 9   Software Development, It Sales, Account Manage...
# 10  Qa, Ui/ux, Java Developer, Java Architect, C++...
# 11  Business Intelligence, Data Warehousing, Data ...
# 12  Office Administration, Hr Administration, tele...
# 13  Social Media, digital media maketing, seo, smm...
# 14  Oracle Dba, Data Science, Data Warehousing, ET...
# 15     Big Data, Hadoop, Data Analytics, Data Science
# 16               Data Science, Python, Data Analytics
# 17  React.js, Data Science, Java, Front End, Busin...
# 18  Qlikview, Qlik Sense, Microsoft Azure, Power B...
# 19  Telecalling, Client Interaction, Marketing, Re...
# 20                                       Data Science
# 21  Corporate Sales, Software Development, Softwar...
# 22  Data Analytics, Data Science, Machine Learning...
# 23  Data Science, Machine Learning, Python, R, Dee...
# 24  Big Data, Data Science, Artificial Intelligenc...
# 25  Java, Net, Angularjs, Hr, Infrastructure, Mana...
# 26  Research, Digital Marketing, Analytics, Softwa...
# 27  Data Science, Artificial Intelligence, Machine...
# 28  Software Architecture, Vp Engineering, Product...
# 29  Data Science, Hadoop, Rpas, Devops, Python, Aw...
# 30  Signal Processing, Machine Learning, Neural Ne...
# 31  Web Technologies, Project Management, Software...
# 32  Server Administartion, Verilog, Vhdl, Digital ...
# 33  Data Science, Machine Learning, Deep Learning,...
# 34  Data Analytics, Managed Services, Team Leading...
# 35  Ethical Hacking, Security Operations Center, S...
# 36  Data Science, Artificial Intelligence, analyti...
# 37  Machine Learning, Artificial Intelligence, Dat...
# 38  C, C++, Artificial Intelligence, Python, Php, ...
# 39  Relationship Management, Retail Sales, Private...
# 40                 Data Science, Software Engineering
# 41  Data Science, Big Data Analytics, Digital Mark...
# 42                  Data Science, Recruitment, Salary
# 43  B.Tech, Tableau, Statistics, R, Analytics, Tim...
# 44  Software Development, Business Intelligence, B...
# 45                   Data Science, Node.js, Angularjs
# 46  Data Science, Media Marketing, Resource Planni...
# 47  Data Analysis, Learning, Data Science, Compute...
# 48  Java, Hadoop, R, Machine Learning, Spark, Flum...
#
#                     Location
# 0                      Delhi
# 1   Hyderabad / Secunderabad
# 2                       Pune
# 3                  Ahmedabad
# 4              UK - (london)
# 5          Vadodara / Baroda
# 6                    Chennai
# 7                 Trivandrum
# 8                     Indore
# 9      Bengaluru / Bangalore
# 10  Hyderabad / Secunderabad
# 11     Bengaluru / Bangalore
# 12                    Mumbai
# 13  Hyderabad / Secunderabad
# 14                 Hyderabad
# 15                    Bhopal
# 16                    Mumbai
# 17                Chandigarh
# 18                      Pune
# 19               Navi Mumbai
# 20                    Cochin
# 21                     Delhi
# 22  Hyderabad / Secunderabad
# 23                      Pune
# 24                      Pune
# 25                      Pune
# 26                   Gurgaon
# 27                      Pune
# 28     Bengaluru / Bangalore
# 29     Bengaluru / Bangalore
# 30                     Delhi
# 31     Bengaluru / Bangalore
# 32                     Noida
# 33           Mysoru / Mysore
# 34  Hyderabad / Secunderabad
# 35     Bengaluru / Bangalore
# 36                 New Delhi
# 37                   Chennai
# 38                   Aligarh
# 39            Salt Lake City
# 40                      Pune
# 41     Bengaluru / Bangalore
# 42                    Mumbai
# 43                    Indore
# 44     Bengaluru / Bangalore
# 45                    MYSORE
# 46  Hyderabad / Secunderabad
# 47     Bengaluru / Bangalore
# 48                    Mumbai

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe")

url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)
time.sleep(5)

# %%
# creating empty lists
Book_name = []
Author_name = []
Volumes_sold = []
Publisher = []
Genre = []


# scraping book names data
for i in driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[2]"):
    Book_name.append(i.text)

    
# scraping author names data
for i in driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[3]"):
    try:
        if i.text == '0' : raise NoSuchElementException
        Author_name.append(i.text)
    except NoSuchElementException:
        Author_name.append('-')
time.sleep(3)


# scraping data of volumes sold
for i in driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[4]"):
    Volumes_sold.append(i.text)
    
    
# scraping data of publisher names
for i in driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[5]"):
    Publisher.append(i.text)
    
    
# scraping  data of genre
for i in driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[6]"):
    Genre.append(i.text)    
    
    
# creating dataframe for scraped data
Novels = pd.DataFrame({})
Novels['Book Name'] = Book_name
Novels['Author'] = Author_name
Novels['Volume sold'] = Volumes_sold
Novels['Publisher'] = Publisher
Novels['Genre'] = Genre
Novels
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [23], in <cell line: 10>()
#       6 Genre = []
#       9 # scraping book names data
# ---> 10 for i in driver.find_elements(By.XPATH,"//table[@class='in-article sortable']/tbody/tr/td[2]"):
#      11     Book_name.append(i.text)
#      14 # scraping author names data
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:860, in WebDriver.find_elements(self, by, value)
#     856     value = f'[name="{value}"]'
#     858 # Return empty list if driver returns null
#     859 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 860 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0081D0D3]
# 	(No symbol) [0x0087EA8B]
# 	(No symbol) [0x0088D093]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75B97D69+25]
# 	RtlInitializeExceptionChain [0x775AB74B+107]
# 	RtlClearBits [0x775AB6CF+191]

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe")

url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)
time.sleep(5)

# %%
# creating empty lists
Name = []
Year_span = []
Genre = []
Run_time = []
Ratings = []
Votes = []

# scraped data of Names
for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
    Name.append(i.text)
    
    
# scraped data of Year span
for i in driver.find_elements(By.XPATH,"//span[@class='lister-item-year text-muted unbold']"):
    Year_span.append(i.text)
    
    
# scraped data of Genre
for i in driver.find_elements(By.XPATH,"//span[@class='genre']"):
    Genre.append(i.text)
    
    
# scraped data of Run time
for i in driver.find_elements(By.XPATH,"//span[@class='runtime']"):
    Run_time.append(i.text)
    
    
# scraped data of Ratings
for i in driver.find_elements(By.XPATH,"//div[@class='ipl-rating-star small']//span[2]"):
    Ratings.append(i.text)
    
    
# scraped data of Votes
for i in driver.find_elements(By.XPATH,"//div[@class='lister-item-content']//p[4]/span[2]"):
    Votes.append(i.text) 
    
    
# creating dataframe for scraped data
TV_Series = pd.DataFrame({})
TV_Series['Name'] = Name
TV_Series['Year Span'] = Year_span
TV_Series['Genre'] = Genre
TV_Series['Run Time'] = Run_time
TV_Series['Ratings'] = Ratings
TV_Series['Votes'] = Votes
TV_Series
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [25], in <cell line: 10>()
#       7 Votes = []
#       9 # scraped data of Names
# ---> 10 for i in driver.find_elements(By.XPATH,"//h3[@class='lister-item-header']/a"):
#      11     Name.append(i.text)
#      14 # scraped data of Year span
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:860, in WebDriver.find_elements(self, by, value)
#     856     value = f'[name="{value}"]'
#     858 # Return empty list if driver returns null
#     859 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 860 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0081D0D3]
# 	(No symbol) [0x0087EA8B]
# 	(No symbol) [0x0088D093]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75B97D69+25]
# 	RtlInitializeExceptionChain [0x775AB74B+107]
# 	RtlClearBits [0x775AB6CF+191]

# %%
driver=webdriver.Chrome(r"C:\Users\su2ny\Downloads\chromedriver_win32\chromedriver.exe")

url = "https://archive.ics.uci.edu/ml/index.php"
driver.get(url)
time.sleep(5)

# %%
# fetching view all dataset button from the webpage
viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")
page_url = viewall_dataset.get_attribute("href")
driver.get(page_url)
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 # fetching view all dataset button from the webpage
# ----> 2 viewall_dataset = driver.find_element(By.XPATH,"//tbody[1]//tr/td[2]/span[2]/a")
#       3 page_url = viewall_dataset.get_attribute("href")
#       4 driver.get(page_url)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0081D0D3]
# 	(No symbol) [0x0087EA8B]
# 	(No symbol) [0x0088D093]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75B97D69+25]
# 	RtlInitializeExceptionChain [0x775AB74B+107]
# 	RtlClearBits [0x775AB6CF+191]

# %%
# fetching page urls of all datasets
view_list = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")
list_url = view_list.get_attribute("href")
driver.get(list_url)
time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [28], in <cell line: 2>()
#       1 # fetching page urls of all datasets
# ----> 2 view_list = driver.find_element(By.XPATH,"/html/body/table[2]/tbody/tr/td[2]/table[1]/tbody/tr/td[2]/p/a")
#       3 list_url = view_list.get_attribute("href")
#       4 driver.get(list_url)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:830, in WebDriver.find_element(self, by, value)
#     827     by = By.CSS_SELECTOR
#     828     value = f'[name="{value}"]'
# --> 830 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0081D0D3]
# 	(No symbol) [0x0087EA8B]
# 	(No symbol) [0x0088D093]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75B97D69+25]
# 	RtlInitializeExceptionChain [0x775AB74B+107]
# 	RtlClearBits [0x775AB6CF+191]

# %%
# fetching urls for each dataset
dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")

urls = []
for i in dataset_url:
    urls.append(i.get_attribute("href"))
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [29], in <cell line: 2>()
#       1 # fetching urls for each dataset
# ----> 2 dataset_url = driver.find_elements(By.XPATH,"//p[@class='normal']//b/a")
#       4 urls = []
#       5 for i in dataset_url:
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:860, in WebDriver.find_elements(self, by, value)
#     856     value = f'[name="{value}"]'
#     858 # Return empty list if driver returns null
#     859 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 860 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:440, in WebDriver.execute(self, driver_command, params)
#     438 response = self.command_executor.execute(driver_command, params)
#     439 if response:
# --> 440     self.error_handler.check_response(response)
#     441     response["value"] = self._unwrap_value(response.get("value", None))
#     442     return response
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:245, in ErrorHandler.check_response(self, response)
#     243         alert_text = value["alert"].get("text")
#     244     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=111.0.5563.111)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x0098DCE3]
# 	(No symbol) [0x009239D1]
# 	(No symbol) [0x00834DA8]
# 	(No symbol) [0x0081D0D3]
# 	(No symbol) [0x0087EA8B]
# 	(No symbol) [0x0088D093]
# 	(No symbol) [0x0087ACC6]
# 	(No symbol) [0x00856F68]
# 	(No symbol) [0x008580CD]
# 	GetHandleVerifier [0x00C03832+2506274]
# 	GetHandleVerifier [0x00C39794+2727300]
# 	GetHandleVerifier [0x00C3E36C+2746716]
# 	GetHandleVerifier [0x00A36690+617600]
# 	(No symbol) [0x0092C712]
# 	(No symbol) [0x00931FF8]
# 	(No symbol) [0x009320DB]
# 	(No symbol) [0x0093C63B]
# 	BaseThreadInitThunk [0x75B97D69+25]
# 	RtlInitializeExceptionChain [0x775AB74B+107]
# 	RtlClearBits [0x775AB6CF+191]

# %%
# creating empty lists
Dataset_name = []
Data_type = []
Task = []
Attribute_type = []
No_of_instances = []
No_of_attributes = []
Year = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    
    
    # scraping  Dataset name
    try:
        dataset_name = driver.find_element(By.XPATH,"//span[@class='heading']")
        Dataset_name.append(dataset_name.text)
    except NoSuchElementException:
        Dataset_name.append('-')
    time.sleep(3)
    
    
    
    # scraping data type
    try:
        data_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[2]")
        if data_type.text == "N/A": raise NoSuchElementException
        Data_type.append(data_type.text)
    except NoSuchElementException:
        Data_type.append('-')
    time.sleep(3)
    
    
    # scraping Task
    try:
        task = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[3]/td[2]")
        if task.text == "N/A": raise NoSuchElementException
        Task.append(task.text)
    except NoSuchElementException:
        Task.append('-')
    time.sleep(3)
    
    
    
    # scraping Attribute type
    try:
        attribute_type = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[2]")
        if attribute_type.text == "N/A": raise NoSuchElementException
        Attribute_type.append(attribute_type.text)
    except NoSuchElementException:
        Attribute_type.append('-')
    time.sleep(3)
    
    
    
    # scraping No of Instances
    try:
        instances = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr/td[4]")
        if instances.text == "N/A": raise NoSuchElementException
        No_of_instances.append(instances.text)
    except NoSuchElementException:
        No_of_instances.append('-')
    time.sleep(3)
    
    
    
    # scraping No of Arrtibutes
    try:
        attribute = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[4]")
        if attribute.text == "N/A": raise NoSuchElementException
        No_of_attributes.append(attribute.text)
    except NoSuchElementException:
        No_of_attributes.append('-')
    time.sleep(3)
    
    
    # scraping Year
    try:
        year = driver.find_element(By.XPATH,"//table[@border='1']//tbody/tr[2]/td[6]")
        if year.text == "N/A": raise NoSuchElementException
        Year.append(year.text[:4])
    except NoSuchElementException:
        Year.append('-')
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 10>()
#       7 No_of_attributes = []
#       8 Year = []
# ---> 10 for i in urls:
#      11     driver.get(i)
#      12     time.sleep(3)
#
# NameError: name 'urls' is not defined
